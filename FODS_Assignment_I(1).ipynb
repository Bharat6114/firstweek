# %% [markdown]
# Book :-
# Author :- Mark Lutz
# 1. Learning Python 5th Edition O'Reilly
# 2.Python Cookbook  David Beazley O'Reilly
#
# Link:-
# 1. http://www.cs.uni.edu/~fienup/cs051f10/lectures/
# 2. https://github.com/MrAlex6204/Books/blob/master/Learning%20Python%2C%205th%20Edition.pdf
# 3. https://github.com/tomarraj008/data_books/blob/master/Python%20Cookbook%2C%203rd%20Edition.pdf

# %% [markdown]
# First Week Assignment
#
# Test Your Knowledge: Quiz
#
# 1. What are the six main reasons that people choose to use Python?
# 2. Name four notable companies or organizations using Python today.
# 3. Why might you not want to use Python in an application?
# 4. What can you do with Python?
# 5. What’s the significance of the Python import this statement?
# 6. Why does “spam” show up in so many Python examples in books and on the Web?
# 7. What is your favorite color?
#
#
# Test Your Knowledge: Quiz
# 1. What is the Python interpreter?
# 2. What is source code?
# 3. What is byte code?
# 4. What is the PVM?
# 5. Name two or more variations on Python’s standard execution model.
# 6. How are CPython, Jython, and IronPython different?
# 7. What are Stackless and PyPy?
#
# Test Your Knowledge: Quiz
# 1. How can you start an interactive interpreter session?
# 2. Where do you type a system command line to launch a script file?
# 3. Name four or more ways to run the code saved in a script file.
# 4. Name two pitfalls related to clicking file icons on Windows.
# 5. Why might you need to reload a module?
# 6. How do you run a script from within IDLE?
# 7. Name two pitfalls related to using IDLE.
# 8. What is a namespace, and how does it relate to module files?
#
#
# Test Your Knowledge: Quiz
#
# 1. Name four of Python’s core data types.
# 2. Why are they called “core” data types?
# 3. What does “immutable” mean, and which three of Python’s core types are considered immutable?
# 4. What does “sequence” mean, and which three types fall into that category?
# 5. What does “mapping” mean, and which core type is a mapping?
# 6. What is “polymorphism,” and why should you care?

# %% [markdown]
# # What are the six main reasons that people choose to use Python?

# %% [markdown]
# 1-open source \
# 2-large comunity\
# 3-easy to learn\
# 4-portable\
# 5-large library\
# 6-we can used python for diverse field such as web development,machine learning,security,data science,AI etc

# %% [markdown]
# # Name four notable companies or organizations using Python today.

# %% [markdown]
# 1-instagram\
# 2-uber\
# 3-Netflix\
# 4-google\
# 5-facebook\
# 6-chrom

# %% [markdown]
# # Why might you not want to use Python in an application?

# %% [markdown]
# python is slow language.

# %% [markdown]
# # What can you do with Python?

# %% [markdown]
# 1-web development\
# 2-data science\
# 3-machine learning\
# 4-AI\
# 5-Game development\
# 6-Automation\
# 7-robotics\
# 8-web scrapping etc

# %% [markdown]
# # What’s the significance of the Python import this statement?

# %% [markdown]
# import statement is used to import python modules

# %% [markdown]
# # What is your favorite color?

# %% [markdown]
# black

# %% [markdown]
# # What is the Python interpreter?

# %% [markdown]
# python  intereter is a program that read and execute code written in python language

# %% [markdown]
# # What is source code?

# %% [markdown]
# source code is a code which is understad by human.
# it is in human readable form and cannot understand by computer directly.

# %% [markdown]
# # What is byte code?

# %% [markdown]
# also caled as machine code and directly understand by computer.
# combination of 0's and 1's.
# difficult to understand by human and difficult to remember.

# %% [markdown]
# # What is the PVM?

# %% [markdown]
# A python virtual machine is simply a program which provides a general programming environment.\
# it helps to execute python program.

# %% [markdown]
# # Name two or more variations on Python’s standard execution model.

# %% [markdown]
# # How are CPython, Jython, and IronPython different?

# %% [markdown]
# Jython runs on the JVM (Java virtual machine) and IronPython runs on the CLR (common language runtime).\
# using Jython, we can write a plugin for a Java application, and using IronPython we can use the .NET standard library.\
# cpython can use the c standard library.

# %% [markdown]
# # What are Stackless and PyPy?

# %% [markdown]
# # How can you start an interactive interpreter session?

# %% [markdown]
# On Windows, bring up the command prompt and type "py", or start an interactive Python session by selecting "Python (command line)"

# %% [markdown]
# # Where do you type a system command line to launch a script file?

# %% [markdown]
#     The operating system command-line or terminal
#     The Python interactive mode
#     The IDE or text editor you like best
#     The file manager of your system, by double-clicking on the icon of your script.

# %% [markdown]
# # What is a namespace, and how does it relate to module files?

# %% [markdown]
# name space is a method to define name of variable so that no conflict are occures in name of the variable.

# %% [markdown]
# # Name four of Python’s core data types.

# %% [markdown]
# 1-number(numeric)\
# 2-sequence\
# 3-set\
# 4-dictionary

# %% [markdown]
# # Why are they called “core” data types?

# %% [markdown]
# because tye are used to make other datatype.\
# and the are used when python is create.

# %% [markdown]
# # What does “immutable” mean, and which three of Python’s core types are considered immutable?

# %% [markdown]
# imutable means unchangeable after defined.\
# we can consider following data type as immutiable\
# 1-Tuple\
# 2-string\
# 3-frozenset

# %% [markdown]
# # What does “sequence” mean, and which three types fall into that category?

# %% [markdown]
# sequence means \
# 1-string\
# 2-list\
# 3-tuple

# %% [markdown]
# # What does “mapping” mean, and which core type is a mapping?

# %% [markdown]
# # What is “polymorphism,” and why should you care?

# %% [markdown]
# **Projects:-**<br>
# 1. Open a Python shell, enter the following expressions, and observe the results:<br>
# a. 8<br>
# b. 8 * 2<br>
# c. 8 ** 2<br>
# d. 8/12<br>
# e. 8 // 12<br>
# f. 8/0

# %%
8
# Out:
# 8

# %%
8*2
# Out:
# 16

# %%
8**2
# Out:
# 64

# %%
8/12
# Out:
# 0.6666666666666666

# %%
8//12
# Out:
# 0

# %%
8/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-b75faf41dc75> in <module>
# ----> 1 8/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 2. Write a Python program that prints (displays) your name, address, and telephone number

# %%
class info:
    def __init__(self,name,address,telephone):
        self.name=name
        self.address= address
        self.telephone=telephone

# %%
b= info("bharat bhandari","kirtipur","9848826114")

# %%
b.name
# Out:
# 'bharat bhandari'

# %%
b.telephone
# Out:
# '9848826114'

# %%
b.address
# Out:
# 'kirtipur'

# %% [markdown]
# 3. Evaluate the following code at a shell prompt: print("Your name is", name). Then assign name an appropriate value, and evaluate the statement again.

# %%
 print("Your name is", name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4ad88697f405> in <module>
# ----> 1 print("Your name is", name)
#
# NameError: name 'name' is not defined

# %%
name="bharat bhandari"
print("your name is",name)
# Out:
# your name is bharat bhandari

# %% [markdown]
# 4. Write and test a program that accepts the user's name(as text) and age(as a number) as input. The program should output a sentense containing the user's name and age.

# %%
name=str(input("please enter your name:"))
age=int(input("please enter your name:"))
print("your name is {} and your age is {}".format(name,age))
# Out:
# please enter your name:bharat bhandari
# please enter your name:24
# your name is bharat bhandari and your age is 24

# %% [markdown]
# 5. Write and test a program that computes the area of a circle. This program should request a number representing  a radius as input from the user. It should use the formula 3.14*radius**2 to compute the area and then output this result suitably labeled.

# %%
def area(radius):
    pi=3.14
    return pi*radius**2

# %%
area(int(input("please enter the radius:")))
# Out:
# please enter the radius:5
# 78.5

# %% [markdown]
# 6. Enter an input statement using the input function at the shll prompt. When the prompt asks you for input, enter a number. Then, attempt to add 1 to that number, observe the results and explain what happened.

# %%
num=input("enter the number")
num+1
# Out:
# enter the number4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-d9b9f4c8e202> in <module>
#       1 num=input("enter the number")
# ----> 2 num+1
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# 7. Enter the expression help() at the shell prompt. Follow the instructions to browse the topics and modules.

# %%
help()
# Out:
# Welcome to Python 3.8's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.8/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> topics
#
# Here is a list of available topics.  Enter any topic name to get more help.
#
# ASSERTION           DELETION            LOOPING             SHIFTING
# ASSIGNMENT          DICTIONARIES        MAPPINGMETHODS      SLICINGS
# ATTRIBUTEMETHODS    DICTIONARYLITERALS  MAPPINGS            SPECIALATTRIBUTES
# ATTRIBUTES          DYNAMICFEATURES     METHODS             SPECIALIDENTIFIERS
# AUGMENTEDASSIGNMENT ELLIPSIS            MODULES             SPECIALMETHODS
# BASICMETHODS        EXCEPTIONS          NAMESPACES          STRINGMETHODS
# BINARY              EXECUTION           NONE                STRINGS
# BITWISE             EXPRESSIONS         NUMBERMETHODS       SUBSCRIPTS
# BOOLEAN             FLOAT               NUMBERS             TRACEBACKS
# CALLABLEMETHODS     FORMATTING          OBJECTS             TRUTHVALUE
# CALLS               FRAMEOBJECTS        OPERATORS           TUPLELITERALS
# CLASSES             FRAMES              PACKAGES            TUPLES
# CODEOBJECTS         FUNCTIONS           POWER               TYPEOBJECTS
# COMPARISON          IDENTIFIERS         PRECEDENCE          TYPES
# COMPLEX             IMPORTING           PRIVATENAMES        UNARY
# CONDITIONAL         INTEGER             RETURNING           UNICODE
# CONTEXTMANAGERS     LISTLITERALS        SCOPING
# CONVERSIONS         LISTS               SEQUENCEMETHODS
# DEBUGGING           LITERALS            SEQUENCES

# %%
help()
# Out:
# Welcome to Python 3.8's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.8/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> methods
# No Python documentation found for 'methods'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %% [markdown]
# 8. The tax calculator program of the case study outputs a floating-point number that might show more than two digits of precision. Use the round function to modify the program to display at most two digits of precision in the output number.

# %%
income=int(input("please enter your income:"))
if(income>0 and income<1000 ):
    tax=income*(10/100)
    round(tax,2)
    print("your tax amount is :",tax)
elif(income>1000 and income<2000):
    tax=income*0.15
    round(tax,2)
    print("your tax amount is :",tax)
else:
    tax=income*0.25
    round(tax,2)
    print("your tax amount is :",tax)
# Out:
# please enter your income:500
# your tax amount is : 50.0

# %% [markdown]
# 9. You can calculate the surface area of a cube if you know the length of an edge. Write a program that takes the length of an edge(an integer) as input and prints the cube's surface area as output.

# %%
def cube(length):
    area=6*length**2
    print("length of cube is ", area)

# %%
cube(int(input("enter the length of cube edge:")))
# Out:
# enter the length of cube edge:4
# length of cube is  96

# %% [markdown]
# 10.Five Star Retro Video rents VHS tapes and DVDs to the same connoisseurs who like to buy LP record albums. The store rents new videos for $3.00 a night, and oldies for $2.00 a night.
#
# Write a program that the clerks at Five Star Retro Video can use to calculate the total charge for a customer’s video rentals.
#
# The program should prompt the user for the number of each type of video and output the total cost.

# %% [markdown]
# 11. Write a program that takes the radius of a sphere(a floating point number) as input and then outputs the sphere's diameter, circumference, surface area and volume.

# %%
radius=float(input("enter the radius of sphere:"))
pi=3.14
diameter=2*radius
circumference=2*pi*radius
area=4*pi*radius**2
volume=(4*(pi*radius**3))/3
print(" sphere diameter is:", diameter)
print("sphere circumference is:", circumference)
print(" sphere area is:", area)
print("sphere volume is:", volume)
# Out:
# enter the radius of sphere:10
#  sphere diameter is: 20.0
# sphere circumference is: 62.800000000000004
#  sphere area is: 1256.0
# sphere volume is: 4186.666666666667

# %% [markdown]
# 12. Instructions An object's momentum is its mass multiplied by its velocity. Write a program that accepts an object's mass (in kilograms) and velocity (in meters per second) as inputs, and then outputs its momentum.

# %%
mass = int(input("enter the mass of object:"))
velocity=int(input("enter the velocity of object:"))
print("momentum of object is:",mass*velocity)
# Out:
# enter the mass of object:10
# enter the velocity of object:20
# momentum of object is: 200

# %% [markdown]
# 13. The kinetic energy of a moving object is given by the formula KE = ½mv2 where m is the object’s mass and v is its velocity.
#
# Modify the program you created in Project 5 so that it prints the object’s kinetic energy as well as its momentum.

# %%
m= int(input("enter the mass of object:"))
v=int(input("enter the velocity of object:"))
print("momentum of object is:",m*v)
print("K.E of object is:",(m*v)/2)
# Out:
# enter the mass of object:10
# enter the velocity of object:10
# momentum of object is: 100
# K.E of object is: 50.0

# %% [markdown]
# 14. An employee’s total weekly pay equals the hourly wage multiplied by the total number of regular hours plus any overtime pay. Overtime pay equals the total overtime hours multiplied by 1.5 times the hourly wage. Write a program that takes as inputs the hourly wage, total regular hours, and total overtime hours and displays an employee’s total weekly pay.

# %%
hourly_wage=int(input("Enter hourly_wage:"))
total_regular_hours=int(input("Enter total regular hours:"))
total_overtime_hours=int(input("Enter total overtime hours:"))
total_overtime_pay = total_overtime_hours*1.5*hourly_wage
if total_overtime_pay:
    print ("total_wekly_pay=",hourly_wage*total_regular_hours+total_overtime_pay)
else:
    print("total_wekly_pay=",hourly_wage*total_regular_hours)
# Out:
# Enter hourly_wage:2
# Enter total regular hours:4
# Enter total overtime hours:4
# total_wekly_pay= 20.0
